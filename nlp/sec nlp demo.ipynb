# %%
#flair ner
from flair.data import Sentence
from flair.models import SequenceTagger

tagger = SequenceTagger.load("flair/ner-english-large")

sentence = Sentence("George Washington went to Washington")
tagger.predict(sentence)
print(sentence)
print('The following NER tags are found:')
for entity in sentence.get_spans('ner'):
    print(entity)
# Out:
# 2023-08-23 14:13:41.865526: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-23 14:13:43.847281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-08-23 14:14:13,405 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# Sentence[5]: "George Washington went to Washington" → ["George Washington"/PER, "Washington"/LOC]
# The following NER tags are found:
# Span[0:2]: "George Washington" → PER (1.0)
# Span[4:5]: "Washington" → LOC (1.0)

# %%
#data aquisition
from bs4 import BeautifulSoup
import requests
import re

url = "https://www.bbc.com/thai/articles/crg7r8gp40jo"
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, "html.parser")
filing_text = soup.get_text()
print(filing_text)
print(re.sub('\s\s+', ' ',filing_text))
# Out:
# มหากาพย์หุ้น STARK: ฟังเสียงแห่งความทุกข์ใจของผู้ถือหุ้นกู้สตาร์ค ที่ถามหาความรับผิดชอบของผู้บริหาร - BBC News ไทยBBC News, ไทยข้ามไปยังเนื้อหาหมวดข่าวหน้าแรกเลือกตั้ง 2566ประเทศไทยต่างประเทศวิทยาศาสตร์สุขภาพวิดีโอยอดนิยมหน้าแรกเลือกตั้ง 2566ประเทศไทยต่างประเทศวิทยาศาสตร์สุขภาพวิดีโอยอดนิยม"ถ้าสตาร์คจะต้องใช้ระยะเวลาฟื้นฟู-แก้ปัญหาถึง 10 ปี ฉันคงไม่มีชีวิตอยู่แล้ว" ที่มาของภาพ, สภาองค์กรของผู้บริโภคArticle informationAuthor, วัชชิรานนท์ ทองเทพRole,  ผู้สื่อข่าวบีบีซีไทย23 มิถุนายน 2023"พูดตรง ๆ นะ มีคนเขาถามฉันอยู่คำหนึ่งว่า ถ้าบริษัทสตาร์คจะต้องใช้ระยะเวลาในการฟื้นฟูหรือแก้ปัญหาถึง 10 ปี ฉันคงไม่มีชีวิตอยู่แล้ว" ผู้ถือหุ้นกู้สูงวัยรายหนึ่งบอกกับบีบีซีไทยนี่คือข้อความจาก มาลี (นามสมมติ) หนึ่งในผู้ถือหุ้นกู้ของ บมจ. สตาร์ค คอร์ปอเรชั่น ที่ต้องการสื่อสารไปยังผู้บริหารของบริษัทที่เธอยอมรับว่า ครั้งหนึ่งเคยเชื่อมั่นและเชื่อใจที่จะนำเงินที่เธอเก็บหอมรอมริบมาตลอดชีวิต ไปลงทุนเพื่อให้ผลิดอกออกผลให้เธอได้นำมาใช้ในบั้นปลายชีวิตที่เหลืออยู่ของเธอขณะที่ผู้เชี่ยวชาญทางการเงินและนักวิเคราะห์จากบริษัทหลักทรัพย์มองว่า ในกรณีที่เลวร้ายที่สุดหากไม่สามารถชำระหนี้ได้ มีความเป็นไปได้ที่ บมจ.สตาร์ค อาจจะขอยื่นต่อศาลล้มละลายกลาง เพื่อทำแผนฟื้นฟูกิจการ ซึ่งอาจจะต้องใช้ระยะเวลาในการดำเนินการมากกว่าระยะเวลาไถ่ถอน"ที่ตัดสินใจซื้อหุ้นกู้ ดิฉันไม่ได้พิจารณาเรื่องผลตอบแทนอย่างเดียว เพราะจริง ๆ แล้วดอกเบี้ยที่ได้ไม่สูงมากเกินไป และที่มองคือต้องการถือครองไม่ยาวมากนักไม่เกินสองปี แต่เน้นในเรื่องความน่าเชื่อถือของบริษัท เรตติ้งดี ๆ  เพราะตอนนี้อายุดิฉันก็มากแล้ว 80 ปีแล้ว"เธอตัดสินใจใช้เงินเก็บ 2 ล้านบาท ไปซื้อหุ้นกู้สองรุ่น คือ STARK242A และ STARK254A พร้อม ๆ กับพี่สาวของเธอสองคนที่มีอายุไล่เลี่ยกัน 82 ปี และ 84 ปี คนละ 2 ล้านบาท ทำให้ทุกวันนี้เธอต้องอาศัยยานอนหลับเพื่อทำให้เธอข่มตาหลับได้Skip เรื่องแนะนำ and continue readingเรื่องแนะนำเลือกตั้ง 2566 : ย้อนคดีธนาธรพ้น ส.ส. ถึงคำร้องสอบพิธาขาดคุณสมบัติ ปม “ถือหุ้นสื่อ” ย้อยรอย 4 ปัจจัยที่ทำให้ "รื่นวดี" ไม่ได้ไปต่อในฐานะเลขาฯ ก.ล.ต.ทำความรู้จักเครดิตสวิส สำคัญอย่างไร ทำไมจึงสั่นสะเทือนตลาดหุ้นไทยและโลกนพพร ศุภพิพัฒน์ VS ณพ ณรงค์เดช + SCB ลุ้นคำตัดสินศาลอังกฤษคดี 5 หมื่นล้านบาทEnd of เรื่องแนะนำเพราะความไว้วางใจเมื่อสอบถามว่า ปัจจัยใดที่ทำให้เธอตกลงปลงใจมาลงทุนกับบริษัทแห่งนี้ สิ่งเดียวที่ผู้ถือหุ้นกู้สตาร์คบอกคือ "ความไว้วางใจ" ทั้งจากความแข็งแกร่งของผลประกอบการนับตั้งแต่บริษัทเข้าตลาดหลักทรัพย์ องค์กรที่ให้คะแนนความน่าเชื่อถือ รวมทั้งภูมิหลังของผู้บริหาร "หุ้นตัวนี้ได้รับการแนะนำโดยหลานที่เป็นลูกของลูกพี่ลูกน้อง ซึ่งเขาดูงบบัญชีเป็น ดูบัญชีย้อนหลังก็ดี และบอกว่า บริษัทนี้มีกำไรถึงสองพันกว่าล้าน" ที่มาของภาพ, สภาองค์กรของผู้บริโภคปัจจัยสำคัญอีกประการหนึ่งคือ ประสบการณ์ส่วนตัวของเธอที่ในอดีตเธอเคยทำงานในวงการธุรกิจวัสดุก่อสร้าง เมื่อเธอพิจารณาภูมิหลังของผู้บริหารของบริษัท ซึ่งอยู่ในแวดวงธุรกิจเดียวกัน ก็ทำให้เธอเองเชื่อมั่นว่า บริษัทที่เธอจะใช้เงินที่เธอเก็บหอมรอมริบมาตลอดชีวิต เข้าร่วมลงทุนไปสามารถผลิดอกออกผลให้เธอได้เก็บกินในช่วงเวลาที่เหลือของชีวิตได้ "ชื่อเสียงของเจ้าสัวดีอยู่แล้ว เพราะฉันเคยทำงานขายเหล็กเส้น ก็เลยไม่ลังเลที่จะซื้อ พี่สาวสองคนก็ซื้อเหมือนกัน และทุก ๆ คนก็ต่างไม่มีครอบครัวกัน ก็หวังว่า เงินที่ลงทุนไปจะช่วยเหลือเจือจุนให้ใช้ชีวิตที่เหลืออยู่อย่างสุขสบาย" เปิดงบการเงิน "สตาร์ค" ปี 64-65 พบความผิดปกติทางบัญชี รวม 2 ปีขาดทุนหนัก 12,640 ล้านแต่เมื่อถามว่าหลังจากนี้จะทำอย่างไรต่อ เธอกล่าวพร้อมน้ำเสียงสิ้นหวังว่า "พูดตรง ๆ นะคะ เงินที่ลงทุนไป ในชาตินี้ก็ไม่มีปัญญา หาไม่ได้แล้ว เพราะตอนนี้ก็ไม่ได้ทำงานแล้ว" มาลีไม่ใช่นักลงทุนหน้าใหม่ เพราะเธอก็กระจายความเสี่ยงด้วยการซื้อและถือครองตราสารหนี้จากสถาบันการเงินอื่น ๆ ด้วย แต่เธอก็ไม่คาดคิดว่า ชะตากรรมที่เหลือของเธอต้องมาเจอกับวิบากกรรมนี้ ที่มาของภาพ, สภาองค์กรของผู้บริโภคขณะที่อมริสา (ขอสงวนนามสกุล) อายุ 26 ปี บอกว่า เงินลงทุนที่นำมาซื้อหุ้นกู้สตาร์ครุ่น 242A มูลค่าราว 2 ล้านบาทจากปีที่แล้ว เป็นเงินจากการหยิบยืมมาจากพ่อและแม่ที่เกษียณอายุราชการแล้ว"ข้อมูลที่ได้รับทั้งจากฝ่ายการตลาดและสื่อมวลชน ก็บ่งชี้ว่า บริษัทได้การจัดอันดับที่ดีในตลาด หรือ investment grade ซึ่งเราก็คิดว่าน่าจะปลอดภัยพอตัว และยังมีข่าวว่าเขามียอดสั่งซื้อไว้แล้วประมาณหมื่นล้านบาท ทำให้เราเข้าใจว่า เขาน่าจะมีกระแสเงินสดจำนวนมากและสามารถคืนเงินต้นให้เราได้ จึงยังไม่เห็นสัญญาณผิดปกติใด ๆ ...
# มหากาพย์หุ้น STARK: ฟังเสียงแห่งความทุกข์ใจของผู้ถือหุ้นกู้สตาร์ค ที่ถามหาความรับผิดชอบของผู้บริหาร - BBC News ไทยBBC News, ไทยข้ามไปยังเนื้อหาหมวดข่าวหน้าแรกเลือกตั้ง 2566ประเทศไทยต่างประเทศวิทยาศาสตร์สุขภาพวิดีโอยอดนิยมหน้าแรกเลือกตั้ง 2566ประเทศไทยต่างประเทศวิทยาศาสตร์สุขภาพวิดีโอยอดนิยม"ถ้าสตาร์คจะต้องใช้ระยะเวลาฟื้นฟู-แก้ปัญหาถึง 10 ปี ฉันคงไม่มีชีวิตอยู่แล้ว" ที่มาของภาพ, สภาองค์กรของผู้บริโภคArticle informationAuthor, วัชชิรานนท์ ทองเทพRole, ผู้สื่อข่าวบีบีซีไทย23 มิถุนายน 2023"พูดตรง ๆ นะ มีคนเขาถามฉันอยู่คำหนึ่งว่า ถ้าบริษัทสตาร์คจะต้องใช้ระยะเวลาในการฟื้นฟูหรือแก้ปัญหาถึง 10 ปี ฉันคงไม่มีชีวิตอยู่แล้ว" ผู้ถือหุ้นกู้สูงวัยรายหนึ่งบอกกับบีบีซีไทยนี่คือข้อความจาก มาลี (นามสมมติ) หนึ่งในผู้ถือหุ้นกู้ของ บมจ. สตาร์ค คอร์ปอเรชั่น ที่ต้องการสื่อสารไปยังผู้บริหารของบริษัทที่เธอยอมรับว่า ครั้งหนึ่งเคยเชื่อมั่นและเชื่อใจที่จะนำเงินที่เธอเก็บหอมรอมริบมาตลอดชีวิต ไปลงทุนเพื่อให้ผลิดอกออกผลให้เธอได้นำมาใช้ในบั้นปลายชีวิตที่เหลืออยู่ของเธอขณะที่ผู้เชี่ยวชาญทางการเงินและนักวิเคราะห์จากบริษัทหลักทรัพย์มองว่า ในกรณีที่เลวร้ายที่สุดหากไม่สามารถชำระหนี้ได้ มีความเป็นไปได้ที่ บมจ.สตาร์ค อาจจะขอยื่นต่อศาลล้มละลายกลาง เพื่อทำแผนฟื้นฟูกิจการ ซึ่งอาจจะต้องใช้ระยะเวลาในการดำเนินการมากกว่าระยะเวลาไถ่ถอน"ที่ตัดสินใจซื้อหุ้นกู้ ดิฉันไม่ได้พิจารณาเรื่องผลตอบแทนอย่างเดียว เพราะจริง ๆ แล้วดอกเบี้ยที่ได้ไม่สูงมากเกินไป และที่มองคือต้องการถือครองไม่ยาวมากนักไม่เกินสองปี แต่เน้นในเรื่องความน่าเชื่อถือของบริษัท เรตติ้งดี ๆ เพราะตอนนี้อายุดิฉันก็มากแล้ว 80 ปีแล้ว"เธอตัดสินใจใช้เงินเก็บ 2 ล้านบาท ไปซื้อหุ้นกู้สองรุ่น คือ STARK242A และ STARK254A พร้อม ๆ กับพี่สาวของเธอสองคนที่มีอายุไล่เลี่ยกัน 82 ปี และ 84 ปี คนละ 2 ล้านบาท ทำให้ทุกวันนี้เธอต้องอาศัยยานอนหลับเพื่อทำให้เธอข่มตาหลับได้Skip เรื่องแนะนำ and continue readingเรื่องแนะนำเลือกตั้ง 2566 : ย้อนคดีธนาธรพ้น ส.ส. ถึงคำร้องสอบพิธาขาดคุณสมบัติ ปม “ถือหุ้นสื่อ” ย้อยรอย 4 ปัจจัยที่ทำให้ "รื่นวดี" ไม่ได้ไปต่อในฐานะเลขาฯ ก.ล.ต.ทำความรู้จักเครดิตสวิส สำคัญอย่างไร ทำไมจึงสั่นสะเทือนตลาดหุ้นไทยและโลกนพพร ศุภพิพัฒน์ VS ณพ ณรงค์เดช + SCB ลุ้นคำตัดสินศาลอังกฤษคดี 5 หมื่นล้านบาทEnd of เรื่องแนะนำเพราะความไว้วางใจเมื่อสอบถามว่า ปัจจัยใดที่ทำให้เธอตกลงปลงใจมาลงทุนกับบริษัทแห่งนี้ สิ่งเดียวที่ผู้ถือหุ้นกู้สตาร์คบอกคือ "ความไว้วางใจ" ทั้งจากความแข็งแกร่งของผลประกอบการนับตั้งแต่บริษัทเข้าตลาดหลักทรัพย์ องค์กรที่ให้คะแนนความน่าเชื่อถือ รวมทั้งภูมิหลังของผู้บริหาร "หุ้นตัวนี้ได้รับการแนะนำโดยหลานที่เป็นลูกของลูกพี่ลูกน้อง ซึ่งเขาดูงบบัญชีเป็น ดูบัญชีย้อนหลังก็ดี และบอกว่า บริษัทนี้มีกำไรถึงสองพันกว่าล้าน" ที่มาของภาพ, สภาองค์กรของผู้บริโภคปัจจัยสำคัญอีกประการหนึ่งคือ ประสบการณ์ส่วนตัวของเธอที่ในอดีตเธอเคยทำงานในวงการธุรกิจวัสดุก่อสร้าง เมื่อเธอพิจารณาภูมิหลังของผู้บริหารของบริษัท ซึ่งอยู่ในแวดวงธุรกิจเดียวกัน ก็ทำให้เธอเองเชื่อมั่นว่า บริษัทที่เธอจะใช้เงินที่เธอเก็บหอมรอมริบมาตลอดชีวิต เข้าร่วมลงทุนไปสามารถผลิดอกออกผลให้เธอได้เก็บกินในช่วงเวลาที่เหลือของชีวิตได้ "ชื่อเสียงของเจ้าสัวดีอยู่แล้ว เพราะฉันเคยทำงานขายเหล็กเส้น ก็เลยไม่ลังเลที่จะซื้อ พี่สาวสองคนก็ซื้อเหมือนกัน และทุก ๆ คนก็ต่างไม่มีครอบครัวกัน ก็หวังว่า เงินที่ลงทุนไปจะช่วยเหลือเจือจุนให้ใช้ชีวิตที่เหลืออยู่อย่างสุขสบาย" เปิดงบการเงิน "สตาร์ค" ปี 64-65 พบความผิดปกติทางบัญชี รวม 2 ปีขาดทุนหนัก 12,640 ล้านแต่เมื่อถามว่าหลังจากนี้จะทำอย่างไรต่อ เธอกล่าวพร้อมน้ำเสียงสิ้นหวังว่า "พูดตรง ๆ นะคะ เงินที่ลงทุนไป ในชาตินี้ก็ไม่มีปัญญา หาไม่ได้แล้ว เพราะตอนนี้ก็ไม่ได้ทำงานแล้ว" มาลีไม่ใช่นักลงทุนหน้าใหม่ เพราะเธอก็กระจายความเสี่ยงด้วยการซื้อและถือครองตราสารหนี้จากสถาบันการเงินอื่น ๆ ด้วย แต่เธอก็ไม่คาดคิดว่า ชะตากรรมที่เหลือของเธอต้องมาเจอกับวิบากกรรมนี้ ที่มาของภาพ, สภาองค์กรของผู้บริโภคขณะที่อมริสา (ขอสงวนนามสกุล) อายุ 26 ปี บอกว่า เงินลงทุนที่นำมาซื้อหุ้นกู้สตาร์ครุ่น 242A มูลค่าราว 2 ล้านบาทจากปีที่แล้ว เป็นเงินจากการหยิบยืมมาจากพ่อและแม่ที่เกษียณอายุราชการแล้ว"ข้อมูลที่ได้รับทั้งจากฝ่ายการตลาดและสื่อมวลชน ก็บ่งชี้ว่า บริษัทได้การจัดอันดับที่ดีในตลาด หรือ investment grade ซึ่งเราก็คิดว่าน่าจะปลอดภัยพอตัว และยังมีข่าวว่าเขามียอดสั่งซื้อไว้แล้วประมาณหมื่นล้านบาท ทำให้เราเข้าใจว่า เขาน่าจะมีกระแสเงินสดจำนวนมากและสามารถคืนเงินต้นให้เราได้ จึงยังไม่เห็นสัญญาณผิดปกติใด ๆ " ...

# %%
for i in range(0,len(filing_text),500):
    sentence = Sentence(filing_text[i:i+500])
    tagger.predict(sentence)
    print(sentence)
    print('The following NER tags are found:')
    for entity in sentence.get_spans('ner'):
        print(entity)
# Out:
# Sentence[36]: "มหากาพย์หุ้น STARK: ฟังเสียงแห่งความทุกข์ใจของผู้ถือหุ้นกู้สตาร์ค ที่ถามหาความรับผิดชอบของผู้บริหาร - BBC News ไทยBBC News, ไทยข้ามไปยังเนื้อหาหมวดข่าวหน้าแรกเลือกตั้ง 2566ประเทศไทยต่างประเทศวิทยาศาสตร์สุขภาพวิดีโอยอดนิยมหน้าแรกเลือกตั้ง 2566ประเทศไทยต่างประเทศวิทยาศาสตร์สุขภาพวิดีโอยอดนิยม"ถ้าสตาร์คจะต้องใช้ระยะเวลาฟื้นฟู-แก้ปัญหาถึง 10 ปี ฉันคงไม่มีชีวิตอยู่แล้ว" ที่มาของภาพ, สภาองค์กรของผู้บริโภคArticle informationAuthor, วัชชิรานนท์ ทองเทพRole,  ผู้สื่อข่าวบีบีซีไทย23 มิถุนายน 2023"พูดตรง ๆ" → ["STARK"/ORG, "BBC News"/ORG, "BBC News"/ORG, "สภาองค์กรของผู้บริโภค"/ORG, "วัชชิรานนท์ ทองเทพRole"/PER]
# The following NER tags are found:
# Span[1:2]: "STARK" → ORG (1.0)
# Span[6:8]: "BBC News" → ORG (1.0)
# Span[9:11]: "BBC News" → ORG (1.0)
# Span[22:23]: "สภาองค์กรของผู้บริโภค" → ORG (1.0)
# Span[26:29]: "วัชชิรานนท์ ทองเทพRole" → PER (0.8619)
# Sentence[17]: "นะ มีคนเขาถามฉันอยู่คำหนึ่งว่า ถ้าบริษัทสตาร์คจะต้องใช้ระยะเวลาในการฟื้นฟูหรือแก้ปัญหาถึง 10 ปี ฉันคงไม่มีชีวิตอยู่แล้ว" ผู้ถือหุ้นกู้สูงวัยรายหนึ่งบอกกับบีบีซีไทยนี่คือข้อความจาก มาลี (นามสมมติ) หนึ่งในผู้ถือหุ้นกู้ของ บมจ. สตาร์ค คอร์ปอเรชั่น ที่ต้องการสื่อสารไปยังผู้บริหารของบริษัทที่เธอยอมรับว่า ครั้งหนึ่งเคยเชื่อมั่นและเชื่อใจที่จะนำเงินที่เธอเก็บหอมรอมริบมาตลอดชีวิต ไปลงทุนเพื่อให้ผลิดอกออกผลให้เธอได้นำมาใช้ในบั้นปลายชีวิตที่เหลืออยู่ของเธอขณะที่ผู้เชี่ยวชาญทางการเงินและนักวิเคราะห์จากบริษ" → ["มาลี"/PER, "บมจ"/ORG, "คอร์ปอเรชั่น"/ORG]
# The following NER tags are found:
# Span[7:8]: "มาลี" → PER (0.9975)
# Span[10:11]: "บมจ" → ORG (0.5056)
# Span[13:14]: "คอร์ปอเรชั่น" → ORG (0.9954)
# Sentence[21]: "ัทหลักทรัพย์มองว่า ในกรณีที่เลวร้ายที่สุดหากไม่สามารถชำระหนี้ได้ มีความเป็นไปได้ที่ บมจ.สตาร์ค อาจจะขอยื่นต่อศาลล้มละลายกลาง เพื่อทำแผนฟื้นฟูกิจการ ซึ่งอาจจะต้องใช้ระยะเวลาในการดำเนินการมากกว่าระยะเวลาไถ่ถอน"ที่ตัดสินใจซื้อหุ้นกู้ ดิฉันไม่ได้พิจารณาเรื่องผลตอบแทนอย่างเดียว เพราะจริง ๆ แล้วดอกเบี้ยที่ได้ไม่สูงมากเกินไป และที่มองคือต้องการถือครองไม่ยาวมากนักไม่เกินสองปี แต่เน้นในเรื่องความน่าเชื่อถือของบริษัท เรตติ้งดี ๆ  เพราะตอนนี้อายุดิฉันก็มากแล้ว 80 ปีแล้ว"เธอตัดสินใจใช้เงินเก็บ 2 ล้านบาท ไปซ" → ["บมจ.สตาร์ค"/ORG]
# The following NER tags are found:
# Span[3:4]: "บมจ.สตาร์ค" → ORG (0.9893)
# Sentence[46]: "ื้อหุ้นกู้สองรุ่น คือ STARK242A และ STARK254A พร้อม ๆ กับพี่สาวของเธอสองคนที่มีอายุไล่เลี่ยกัน 82 ปี และ 84 ปี คนละ 2 ล้านบาท ทำให้ทุกวันนี้เธอต้องอาศัยยานอนหลับเพื่อทำให้เธอข่มตาหลับได้Skip เรื่องแนะนำ and continue readingเรื่องแนะนำเลือกตั้ง 2566 : ย้อนคดีธนาธรพ้น ส.ส. ถึงคำร้องสอบพิธาขาดคุณสมบัติ ปม “ถือหุ้นสื่อ” ย้อยรอย 4 ปัจจัยที่ทำให้ "รื่นวดี" ไม่ได้ไปต่อในฐานะเลขาฯ ก.ล.ต.ทำความรู้จักเครดิตสวิส สำคัญอย่างไร ทำไมจึงสั่นสะเทือนตลาดหุ้นไทยและโลกนพพร ศุภพิพัฒน์ VS ณพ ณรงค์เดช + SCB ลุ้นคำตัดส" → ["ก.ล.ต.ทำความรู้จักเครดิตสวิส"/ORG, "ศุภพิพัฒน์"/PER, "ณพ ณรงค์เดช"/PER, "SCB"/ORG]
# The following NER tags are found:
# Span[36:37]: "ก.ล.ต.ทำความรู้จักเครดิตสวิส" → ORG (0.9999)
# Span[39:40]: "ศุภพิพัฒน์" → PER (1.0)
# Span[41:43]: "ณพ ณรงค์เดช" → PER (1.0)
# Span[44:45]: "SCB" → ORG (1.0)
# Sentence[20]: "ินศาลอังกฤษคดี 5 หมื่นล้านบาทEnd of เรื่องแนะนำเพราะความไว้วางใจเมื่อสอบถามว่า ปัจจัยใดที่ทำให้เธอตกลงปลงใจมาลงทุนกับบริษัทแห่งนี้ สิ่งเดียวที่ผู้ถือหุ้นกู้สตาร์คบอกคือ "ความไว้วางใจ" ทั้งจากความแข็งแกร่งของผลประกอบการนับตั้งแต่บริษัทเข้าตลาดหลักทรัพย์ องค์กรที่ให้คะแนนความน่าเชื่อถือ รวมทั้งภูมิหลังของผู้บริหาร "หุ้นตัวนี้ได้รับการแนะนำโดยหลานที่เป็นลูกของลูกพี่ลูกน้อง ซึ่งเขาดูงบบัญชีเป็น ดูบัญชีย้อนหลังก็ดี และบอกว่า บริษัทนี้มีกำไรถึงสองพันกว่าล้าน" ที่มาของภาพ, สภาองค์กรของผู้บริโภคปัจจัยสำ" → ["หมื่นล้านบาท"/ORG, "สภาองค์กรของผู้บริโภคปัจจัยสำ"/ORG]
# The following NER tags are found:
# Span[2:3]: "หมื่นล้านบาท" → ORG (0.9438)
# Span[19:20]: "สภาองค์กรของผู้บริโภคปัจจัยสำ" → ORG (0.9438)
# Sentence[16]: "คัญอีกประการหนึ่งคือ ประสบการณ์ส่วนตัวของเธอที่ในอดีตเธอเคยทำงานในวงการธุรกิจวัสดุก่อสร้าง เมื่อเธอพิจารณาภูมิหลังของผู้บริหารของบริษัท ซึ่งอยู่ในแวดวงธุรกิจเดียวกัน ก็ทำให้เธอเองเชื่อมั่นว่า บริษัทที่เธอจะใช้เงินที่เธอเก็บหอมรอมริบมาตลอดชีวิต เข้าร่วมลงทุนไปสามารถผลิดอกออกผลให้เธอได้เก็บกินในช่วงเวลาที่เหลือของชีวิตได้ "ชื่อเสียงของเจ้าสัวดีอยู่แล้ว เพราะฉันเคยทำงานขายเหล็กเส้น ก็เลยไม่ลังเลที่จะซื้อ พี่สาวสองคนก็ซื้อเหมือนกัน และทุก ๆ คนก็ต่างไม่มีครอบครัวกัน ก็หวังว่า เงินที่ลงทุนไปจะช่วยเหลื"
# The following NER tags are found:
# Sentence[28]: "อเจือจุนให้ใช้ชีวิตที่เหลืออยู่อย่างสุขสบาย" เปิดงบการเงิน "สตาร์ค" ปี 64-65 พบความผิดปกติทางบัญชี รวม 2 ปีขาดทุนหนัก 12,640 ล้านแต่เมื่อถามว่าหลังจากนี้จะทำอย่างไรต่อ เธอกล่าวพร้อมน้ำเสียงสิ้นหวังว่า "พูดตรง ๆ นะคะ เงินที่ลงทุนไป ในชาตินี้ก็ไม่มีปัญญา หาไม่ได้แล้ว เพราะตอนนี้ก็ไม่ได้ทำงานแล้ว" มาลีไม่ใช่นักลงทุนหน้าใหม่ เพราะเธอก็กระจายความเสี่ยงด้วยการซื้อและถือครองตราสารหนี้จากสถาบันการเงินอื่น ๆ ด้วย แต่เธอก็ไม่คาดคิดว่า ชะตากรรมที่เหลือของเธอต้องมาเจอกับวิบากกรรมนี้ ที่มาของภาพ, สภาองค์กรขอ" → ["มาลีไม่ใช่นักลงทุนหน้าใหม่"/PER]
# The following NER tags are found:
# Span[19:20]: "มาลีไม่ใช่นักลงทุนหน้าใหม่" → PER (1.0)
# Sentence[23]: "งผู้บริโภคขณะที่อมริสา (ขอสงวนนามสกุล) อายุ 26 ปี บอกว่า เงินลงทุนที่นำมาซื้อหุ้นกู้สตาร์ครุ่น 242A มูลค่าราว 2 ล้านบาทจากปีที่แล้ว เป็นเงินจากการหยิบยืมมาจากพ่อและแม่ที่เกษียณอายุราชการแล้ว"ข้อมูลที่ได้รับทั้งจากฝ่ายการตลาดและสื่อมวลชน ก็บ่งชี้ว่า บริษัทได้การจัดอันดับที่ดีในตลาด หรือ investment grade ซึ่งเราก็คิดว่าน่าจะปลอดภัยพอตัว และยังมีข่าวว่าเขามียอดสั่งซื้อไว้แล้วประมาณหมื่นล้านบาท ทำให้เราเข้าใจว่า เขาน่าจะมีกระแสเงินสดจำนวนมากและสามารถคืนเงินต้นให้เราได้ จึงยังไม่เห็นสัญญาณผิดปกติใด ๆ"
# The following NER tags are found:
# Sentence[35]: " " จากบริษัทดาวรุ่ง SET100 สู่หุ้น 1 สตางค์การกลับมาเปิดการซื้อขายอีกครั้งหลังจากถูกระงับมาเป็นเวลา 3 เดือน แม้ว่าจะส่งงบประจำปี 2565 ไปแล้ว แต่ด้วยความมีพิรุธและผู้ตรวจสอบบัญชีไม่แสดงความเห็นต่องบการเงิน รวมทั้งกรณีการตรวจสอบเป็นกรณีพิเศษที่ขอขยายระยะเวลาออกไปอีก 30 วัน (สิ้นสุดวันที่ 17 ก.ค.) ทำให้สถานการณ์ของบริษัทยังมีแนวโน้มน่าเป็นห่วงราคาหุ้นดิ่งลงทุกวัน โดยในวันที่ 21 มิ.ย. ราคาหล่นมาอยู่ที่ 0.01 บาทต่อหุ้น ถือว่าต่ำที่สุด ขณะที่ราคาที่เคยทำได้สูงสุดอยู่ที่ 5.10 บาท ในเดือน พ.ค. 2565 ที่ม" → ["SET100"/MISC]
# The following NER tags are found:
# Span[2:3]: "SET100" → MISC (0.9998)
# Sentence[25]: "าของภาพ, บมจ.สตาร์ค คอร์ปอเรชั่น คำบรรยายภาพ, ภาพประชาสัมพันธ์จาก บมจ.สตาร์ค ที่อ้างอิงถึงผลการจัดอันดับความน่าเชื่อถือโดยทริสเรตติ้งย้อนหลังกลับไป บมจ.สตาร์ค ครั้งหนึ่งเคยเป็นองค์กรที่น่าจับตาที่สุดแห่งหนึ่งในตลาดหลักทรัพย์ด้วยการติดทำเนียบ "SET100" หรือ หุ้น 100 อันดับแรกที่คัดเลือกโดยตลาดหลักทรัพย์แห่งประเทศไทย (ตลท.) หลังจากเข้าสู่ตลาดหุ้นได้ไม่นานก็สามารถทำกำไรแบบก้าวกระโดดจากหลักร้อยล้านสู่หลักพันล้าน ขณะที่ บริษัท ทริสเรทติ้ง จำกัด ผู้จัดอันดับความน่าเชื่อถือของบริษัทในตลาดหลักทรัพย์ได้เค" → ["บมจ.สตาร์ค คอร์ปอเรชั่น"/ORG, "บมจ.สตาร์ค"/ORG, "บมจ.สตาร์ค"/ORG, "SET100"/MISC, "บริษัท ทริสเรทติ้ง จำกัด"/ORG]
# The following NER tags are found:
# Span[2:4]: "บมจ.สตาร์ค คอร์ปอเรชั่น" → ORG (0.9965)
# Span[7:8]: "บมจ.สตาร์ค" → ORG (0.993)
# Span[9:10]: "บมจ.สตาร์ค" → ORG (0.9964)
# Span[12:13]: "SET100" → MISC (0.9941)
# Span[21:24]: "บริษัท ทริสเรทติ้ง จำกัด" → ORG (0.9996)
# Sentence[33]: "ยให้อันดับเครดิตองค์กรของ บมจ. สตาร์ค ที่ระดับ “BBB+” เมื่อช่วง มี.ค. 2564 อีกด้วย เนื่องจากมองว่ากลยุทธ์ของบริษัทที่มุ่งเน้นผลิตภัณฑ์ในกลุ่มสายไฟฟ้าแรงดันปานกลางจนถึงแรงดันสูงเป็นพิเศษนั้นมีบทบาทสำคัญที่ทำให้ความสามารถในการทำกำไรของบริษัทแข็งแกร่งยิ่งขึ้น  อย่างไรก็ตาม หลังจาก บมจ. สตาร์ค เผชิญกับปัญหาการส่งงบการเงิน ทำให้ถูกปรับอันดับลงเรื่อย ๆ จนครั้งล่าสุดเมื่อวันที่ 2 มิ.ย. หลังจากที่บริษัทได้ผิดนัดชำระดอกเบี้ยสำหรับหุ้นกู้บางรุ่น (STARK239A และ STARK249A) ทำให้ทริสเรทติ้งปรับลดอันดับเครดิต" → ["บมจ."/ORG, "บมจ."/ORG]
# The following NER tags are found:
# Span[1:3]: "บมจ." → ORG (0.9998)
# Span[16:18]: "บมจ." → ORG (0.9998)
# Sentence[29]: "องค์กรลงสู่ระดับ “D” ซึ่งถือว่าเป็นระดับเครดิตที่แย่ที่สุด คาดมูลค่าความเสียหายหมื่นล้านบาท ที่มาของภาพ, Getty Imagesมาลีไม่ใช่ผู้เสียหายคนเดียวที่ต้องเจอกับปัญหานี้ เพราะตอนนี้ บมจ. สตาร์ค ยังมีหุ้นกู้ที่ต้องชำระให้กับนักลงทุนถึง 5 รุ่น เป็นจำนวนเงินรวมกว่า 9,200 ล้านบาท หลังจากที่บริษัทไม่สามารถส่งงบการเงินปีที่แล้วได้ตามกำหนดภายหลังการแจ้งงบการเงินประจำปี 2565 ต่อตลาดหลักทรัพย์แล้ว กลับพบกับข้อพิรุธต่าง ๆ ไม่ว่าจะเป็นการปรับแต่งบัญชี การสร้างยอดขายปลอม รวมทั้งการระดมเงินไปแล้วกลับเปลี่ยนแปลงว" → ["Getty Images"/ORG, "มาลีไม่ใช่ผู้เสียหายคนเดียวที่ต้องเจอกับปัญหานี้"/ORG, "บมจ."/ORG]
# The following NER tags are found:
# Span[8:10]: "Getty Images" → ORG (1.0)
# Span[10:11]: "มาลีไม่ใช่ผู้เสียหายคนเดียวที่ต้องเจอกับปัญหานี้" → ORG (0.9999)
# Span[12:14]: "บมจ." → ORG (0.9998)
# Sentence[31]: "ัตถุประสงค์ของการใช้เงิน แต่กลับไม่คืนเงินแก่ผู้ลงทุน สิ่งที่ทำให้บรรดานักลงทุนประหลาดใจคือ การแต่งบัญชีให้มีกำไร ทั้งที่จริง ๆ แล้วในปี 2565 ขาดทุนกว่า 6,651 ล้านบาท ขณะที่ปี 2564 จากเดิมที่เคยรายงานว่ามีกำไรกว่า 2,794.9 ล้านบาท แต่เมื่อปรับปรุงตัวเลขแล้ว พบว่ากลับเป็นขาดทุนกว่า 5,989.3 ล้านบาทที่มาของภาพ, บมจ.สตาร์ค คอร์ปอเรชั่นคำบรรยายภาพ, ผลประกอบการประจำปี 2565 และ 2564 ที่ได้รับการแก้ไขแล้วพ่อและแม่ของอุกฤษณ์ อภิวัฒนานนท์ เป็นอีกสองผู้เสียหายที่กำลังเผชิญกับความเสี่ยงแบบเดียวกันกับมาลีและอ" → ["คอร์ปอเรชั่นคำบรรยายภาพ"/ORG, "อภิวัฒนานนท์"/PER]
# The following NER tags are found:
# Span[22:23]: "คอร์ปอเรชั่นคำบรรยายภาพ" → ORG (0.9999)
# Span[29:30]: "อภิวัฒนานนท์" → PER (0.823)
# Sentence[24]: "มริสา โดยตัวเขาเองหวังเพียงให้หน่วยงานรัฐที่เกี่ยวข้องเข้ามาช่วยเหลือ และขอเพียงให้ได้เงินต้นคืนก็ถือว่าดีแล้ว เพราะเงินที่พ่อแม่ของเขานำไปลงทุนก็เป็นมูลค่าสูงเช่นกัน "ทั้งพ่อและแม่ มองว่าหุ้นสตาร์คมีพื้นฐาน และมีหน่วยงานการันตี รวมทั้งผ่านหลักเกณฑ์ต่าง ๆ ที่ทั้งตลาดหลักทรัพย์และ ก.ล.ต. ตรวจสอบ จึงไม่ได้ระแคะระคายใด ๆ ทำให้ทั้งสองคนยอมใช้เงินเก็บคนละ 1.5 ล้านบาท ไปลงทุนกับหุ้นกู้" เขาอธิบาย "คนที่มีความคาดหวังในการลงทุนเพื่อจะมีรายได้เข้า แต่เงินต้นกลับหาย เงินที่คาดว่าจะได้ก็ไม่ได้ ความทุกข์ใจข" → ["มริสา"/PER, "ก.ล.ต"/ORG]
# The following NER tags are found:
# Span[0:1]: "มริสา" → PER (0.9604)
# Span[10:11]: "ก.ล.ต" → ORG (0.9951)
# Sentence[16]: "องเขาก็ต้องเก็บไว้ เพื่อไม่ให้ลูกรู้สึกเครียด อยู่ในภาวะน้ำท่วมปาก" ผู้บริหารควรแสดงวุฒิภาวะ-ความรับผิดชอบมากกว่านี้หรือไม่สิ่งที่ผู้ถือหุ้นทั้ง 3 รายเห็นตรงกันคือ อยากเห็นผู้บริหารออกมาแสดงความรับผิดชอบต่อเหตุการณ์ที่เกิดขึ้นมากกว่านี้ พร้อมกับอยากให้ชี้แจงเหตุการณ์ที่เกิดขึ้นและมาตรการต่อไปสำหรับผู้ถือหุ้นทุกกลุ่ม  แม้ว่าอุกฤษณ์ จะไม่ใช่ผู้ได้รับผลกระทบโดยตรง แต่เขาเทียบเคียงกับประสบการณ์ในฐานะที่เป็นผู้ประกอบธุรกิจคนหนึ่งว่า "ถ้ามองในความเป็นจริง จากงบการเงิน ไม่มีทางที่บริษัทนี้ (สตาร์ค) จะไ" → ["ผู้บริหารควรแสดงวุฒิภาวะ-ความรับผิดชอบมากกว่านี้หรือไม่สิ่งที่ผู้ถือหุ้นทั้ง"/ORG]
# The following NER tags are found:
# Span[3:4]: "ผู้บริหารควรแสดงวุฒิภาวะ-ความรับผิดชอบมากกว่านี้หรือไม่สิ่งที่ผู้ถือหุ้นทั้ง" → ORG (0.9049)
# Sentence[20]: "ปต่อได้เลย"อย่างไรก็ตาม ถึงแม้ว่าธุรกิจจะประสบกับปัญหา "ความจริงใจต่อลูกค้า" ก็สำคัญเช่นกัน "สำหรับธุรกิจวัตถุดิบอาหาร สิ่งหนึ่งที่ผมมีคือ ความซื่อสัตย์กับลูกค้า ถ้ามีปัญหาอะไรก็ต้องแจ้งกับลูกค้า แต่การที่เป็นบริษัทมหาชนที่ยิ่งใหญ่และเปิดขายหุ้นให้กับประชาชน โดยไม่เปิดข้อมูลใด ๆ ที่มีประโยชน์ให้กับผู้ถือหุ้นที่เป็นเจ้าหนี้ โดยเฉพาะประชาชน ซึ่งเป็นเจ้าหนี้รายย่อย ไม่มีอำนาจจะรู้ความเป็นจริงเป็นอย่างไร ให้เข้าใจสถานการณ์อย่างไร จะดำเนินการต่อไปอย่างไร" เขาตั้งคำถามที่มาของภาพ, สภาองค์กรของผู้บริโภ"
# The following NER tags are found:
# Sentence[18]: "คคำบรรยายภาพ, บรรยากาศการหารือระหว่างผู้ถือหุ้นกู้สตาร์คและเจ้าหน้าที่ ก.ล.ต. เมื่อวันที่ 12 มิ.ย.นอกจากนี้ เขายังได้ยกตัวอย่างกรณีคุณพ่อที่ก็เคยประสบปัญหาในลักษณะเดียวกันจากการถือหุ้นของบริษัทภูเก็ตแฟนตาซี ที่ขาดสภาพคล่องหลังได้รับผลกระทบจากวิกฤตโควิด-19 ทำให้นักท่องเที่ยวลดลง ทางบริษัทฯ ก็ได้ติดต่อประสานงานมาเพื่อเสนอช่องทางในการแก้ไขให้กับผู้ถือหุ้นกู้ ไม่ว่าจะเป็นเรื่องการอธิบายว่า ไม่สามารถทยอยจ่ายดอกเบี้ยให้ได้ โดยขอยื่นเสนอขยายอายุสัญญาออกไป "ผมเชื่อว่าการเป็นลูกหนี้ที่ดีคุณจะต้องมีการบริ" → ["ก.ล.ต"/ORG, "19"/MISC]
# The following NER tags are found:
# Span[3:4]: "ก.ล.ต" → ORG (0.9941)
# Span[10:11]: "19" → MISC (0.9991)
# Sentence[29]: "หารจัดการที่ถูกต้อง แต่ไม่ใช่คุณหลบหน้า แสดงว่าคุณไม่มีวุฒิภาวะหรือความเป็นผู้นำเลยหรือไม่" เขาตั้งคำถามขณะที่มาลี ก็ขอเรียกร้องผู้บริหารของสตาร์คเช่นกัน"ดิฉันอยากให้เขาออกมารับผิดชอบเรื่องนี้ เพราะทุก ๆ คนที่เสียหายต่างพูดกันไม่ออกแล้ว น้ำตาจะไหลแล้ว บางคนบอกว่า ในส่วนของเขา (ที่ลงทุนไป) ก็ไม่เยอะ แต่เขาเก็บหอมรอมริบมาแทบตาย และคิดว่าจะได้ดอกเบี้ยมา แต่ก็กลับกลายเป็นอย่างนี้ ดอกเบี้ยไม่ได้ ต้นก็ไม่ได้ แล้วจะให้ฉันทำอย่างไร" ที่มาของภาพ, บมจ.สตาร์ค คอร์ปอเรชั่น ขณะที่วันที่ 21 มิ.ย. ที่ผ่านมา บม" → ["คอร์ปอเรชั่น"/ORG]
# The following NER tags are found:
# Span[22:23]: "คอร์ปอเรชั่น" → ORG (0.9834)
# Sentence[35]: "จ. สตาร์ค ได้แจ้งต่อตลาดหลักทรัพย์แห่งประเทศไทยว่า ได้ยกเลิกการจัดประชุมผู้ถือหุ้นกู้ครั้งที่ 3/2566 สำหรับหุ้นกู้ 3 รุ่น ประกอบด้วย STARK245A, STARK255A และ STARK242A ไปแล้ว เนื่องจากเมื่อวันที่ 20 มิ.ย. ผู้แทนผู้ถือหุ้นกู้ได้ส่งหนังสือถึง บมจ. สตาร์ค ขอให้ชำระหนี้เงินต้นและดอกเบี้ยคงค้างหุ้นกู้ทั้งหมดโดยพลัน โดยอาศัยเหตุผิดนัดเนื่องจากผู้ออกหุ้นกู้ได้ผิดนัดชำระหนี้เกินกว่า 3.00% ของส่วนของผู้ถือหุ้นของผู้ออกหุ้นกู้โดยคำนวณจากงบการเงินรวมปี 2565 อย่างไรก็ตาม การยกเลิกดังกล่าว บริษัทฯ อ้างว่าเพื" → ["จ."/ORG, "บมจ."/ORG]
# The following NER tags are found:
# Span[0:1]: "จ." → ORG (0.9999)
# Span[22:24]: "บมจ." → ORG (0.86)
# Sentence[23]: "่อรักษาความเป็นธรรมต่อกลุ่มเจ้าหนี้ทางการเงินรายอื่น ๆ ด้วยบทเรียนของผู้กำกับตลาดหลายกรณีที่เกิดขึ้นที่ส่งผลกระทบต่อผู้ลงทุนหรือผู้ถือหุ้นกู้ จากบริษัทที่ดำเนินการระดมทุนในตลาดหลักทรัพย์ฯ ทำให้เกิดคำถามต่อผู้ที่กำกับดูแลว่า มีมาตรการในการควบคุมและตรวจสอบบริษัทเหล่านั้นเพียงพอหรือไม่ ล่าสุดวันที่ 21 มิ.ย. คณะกรรมการตลาดหลักทรัพย์ฯ มีมติเห็นชอบแนวทางให้ปรับปรุงหลักเกณฑ์สำหรับบริษัทจดทะเบียนตลาดหลักทรัพย์แห่งประเทศไทย (SET) และตลาดหลักทรัพย์เอ็ม เอ ไอ (mai) ทั้งกระบวนการ เพื่อสนับสนุนบริษัทที่มีฐาน" → ["ทำให้เกิดคำถามต่อผู้ที่กำกับดูแลว่า"/ORG, "คณะกรรมการตลาดหลักทรัพย์ฯ"/ORG, "SET"/ORG, "เอ ไอ"/ORG, "mai"/ORG]
# The following NER tags are found:
# Span[4:5]: "ทำให้เกิดคำถามต่อผู้ที่กำกับดูแลว่า" → ORG (0.9995)
# Span[10:11]: "คณะกรรมการตลาดหลักทรัพย์ฯ" → ORG (0.9995)
# Span[13:14]: "SET" → ORG (0.9997)
# Span[16:18]: "เอ ไอ" → ORG (1.0)
# Span[19:20]: "mai" → ORG (0.9997)
# Sentence[26]: "ะทางการเงินและผลการดำเนินงานแข็งแกร่ง ให้สามารถใช้ประโยชน์จากตลาดทุนได้ ที่มาของภาพ, Getty Imagesในเอกสารประชาสัมพันธ์ที่อ้างอิงถึงคำพูดของนายภากร ปีตธวัชชัย กรรมการและผู้จัดการตลาดหลักทรัพย์ฯ ยังระบุเพิ่มเติมอีกว่าต้องการยกระดับการกำกับดูแลเพิ่มมากขึ้นด้วยการปรับปรุงเกณฑ์เครื่องหมาย "C (Caution)" เกณฑ์เพิกถอน ตลอดจนเกณฑ์การเข้าสู่ตลาดหุ้นโดยทางอ้อม หรือ Backdoor Listing เพื่อเพิ่มคุณภาพบริษัทจดทะเบียน และดูแลผู้ลงทุน โดยจะเปิดรับฟังความเห็นจากผู้เกี่ยวข้องภายในไตรมาส 3 ปีนี้ที่มาผ่าน มีหลายบริษ" → ["Getty Images"/ORG, "ปีตธวัชชัย"/PER]
# The following NER tags are found:
# Span[4:6]: "Getty Images" → ORG (1.0)
# Span[7:8]: "ปีตธวัชชัย" → PER (1.0)
# Sentence[16]: "ัทใช้วิธีการเข้าสู่ตลาดหุ้นโดยทางอ้อม หนึ่งในจำนวนนั้นคือ บมจ.สตาร์ค ที่ให้ บมจ.สยามอินเตอร์ มัลติมีเดีย ซึ่งอยู่ในกลุ่มธุรกิจสิ่งพิมพ์ เข้าไปซื้อกิจการในปี 2562  ก่อนที่จะเปลี่ยนชื่อบริษัทและวัตถุประสงค์การทำธุรกิจมาเป็นผู้ผลิตสายไฟฟ้าและสายเคเบิล เพื่อให้บริการภาคอุตสาหกรรมข่าวที่เกี่ยวข้องเศรษฐกิจธุรกิจการธนาคารการเงินส่วนบุคคลประเทศไทยเงินตราการเป็นเจ้าของกิจการตลาดหลักทรัพย์ข่าวเด่นสื่อนอกชี้เพื่อไทยทำ "สัญญาปีศาจ" แลกเป็นรัฐบาล-ทักษิณกลับไทย ส่อแววไร้เสถียรภาพเมื่อ 2 ชั่วโมงที่แล้วโฆษกประธ" → ["บมจ.สตาร์ค"/ORG, "บมจ.สยามอินเตอร์ มัลติมีเดีย"/ORG]
# The following NER tags are found:
# Span[2:3]: "บมจ.สตาร์ค" → ORG (0.999)
# Span[4:6]: "บมจ.สยามอินเตอร์ มัลติมีเดีย" → ORG (0.9999)
# Sentence[46]: "านสภาเผย โปรดเกล้าฯ แต่งตั้ง เศรษฐา ทวีสิน เป็นนายกฯ แล้วเมื่อ 3 ชั่วโมงที่แล้วย้ายตัวทักษิณจากเรือนจำไป รพ.ตำรวจ กลางดึกเมื่อ 4 ชั่วโมงที่แล้วเรื่องน่าสนใจเอเวอร์แกรนด์ของจีนล้มละลาย จะสะเทือนโลกเหมือน “เลห์แมน บราเธอร์ส” ล่มสลาย หรือไม่ ?18 สิงหาคม 2023ศาลอังกฤษตัดสิน "ลูซี เลตบี" พยาบาลสาว “ผู้ชั่วร้าย” มีความผิด ฐานฆ่าทารกแรกเกิด 7 ราย18 สิงหาคม 2023เอเวอร์แกรนด์ เจ้าพ่ออสังหาฯ จีน ยื่นล้มละลายในสหรัฐฯ หลังแบกหนี้กว่า 3 แสนล้านดอลลาร์18 สิงหาคม 2023วิกฤตป่าชายเลนอินโดนีเซีย เมื่อชาวบ้านโค่นต" → ["เศรษฐา ทวีสิน"/PER, "บราเธอร์ส”"/ORG, "เลตบี""/PER, "เอเวอร์แกรนด์"/ORG]
# The following NER tags are found:
# Span[3:5]: "เศรษฐา ทวีสิน" → PER (0.9996)
# Span[15:16]: "บราเธอร์ส”" → ORG (0.9767)
# Span[24:25]: "เลตบี"" → PER (1.0)
# Span[34:35]: "เอเวอร์แกรนด์" → ORG (1.0)
# Sentence[48]: "้นโกงกางมาเผาถ่านขาย16 สิงหาคม 2023ไฟป่าฮาวาย กลายเป็นไฟป่าร้ายแรงที่สุดของสหรัฐฯ ในรอบกว่า 100 ปี เสียชีวิตแล้ว 99 ศพ15 สิงหาคม 2023ตั้งข้อหา โดนัลด์ ทรัมป์ กับพวก ฐานพยายามล้มผลเลือกตั้งประธานาธิบดีปี 202015 สิงหาคม 2023"เราจนจริง ๆ แต่เราจะไปแสดงเหมือนขอทานอย่างนั้นหรือ"18 สิงหาคม 2023ธุรกิจหรืองมงาย ? มองกระแสบูชา “ครูกายแก้ว” ในมุมศาสนวิทยาและพระพุทธศาสนา17 สิงหาคม 2023ผมเป็นหนี้บุญคุณช้างเพื่อนแก้ว17 สิงหาคม 2023ได้รับความนิยมสูงสุด1ย้ายตัวทักษิณจากเรือนจำไป รพ.ตำรวจ กลางดึก2สื่อนอกชี้เพื่" → ["โดนัลด์ ทรัมป์"/PER]
# The following NER tags are found:
# Span[16:18]: "โดนัลด์ ทรัมป์" → PER (1.0)
# Sentence[45]: "อไทยทำ "สัญญาปีศาจ" แลกเป็นรัฐบาล-ทักษิณกลับไทย ส่อแววไร้เสถียรภาพ3โลกร้อนเปิดทางรักให้นีแอนเดอร์ทัล ได้จับคู่ข้ามสายพันธุ์กับเดนิโซวาน4มติรัฐสภา 482:165 โหวต เศรษฐา ทวีสิน นั่งนายกฯ 100 วันหลังเลือกตั้ง5เพื่อไทยปิดดีลรัฐบาล 314 เสียง แจกเก้าอี้ ครม. 6 พรรค มั่นใจเสียงโหวตหนุนเศรษฐานั่งเก้าอี้นายกฯBBC News, ไทยทำไมคุณจึงไว้วางใจ บีบีซี ได้เงื่อนไขการใช้งานของ บีบีซีเกี่ยวกับบีบีซีนโยบายความเป็นส่วนตัวคุกกีส์ติดต่อบีบีซีDo not share or sell my info© 2023 บีบีซี. บีบีซีไม่มีส่วนรับผิดชอบต่อเนื้อหา" → ["อไทยทำ"/PER, "มติรัฐสภา"/ORG, "เศรษฐา ทวีสิน"/PER, "เพื่อไทยปิดดีลรัฐบาล"/ORG, "BBC News"/ORG, "ไทยทำไมคุณจึงไว้วางใจ"/LOC, "บีบีซี"/ORG, "บีบีซีเกี่ยวกับบีบีซีนโยบายความเป็นส่วนตัวคุกกีส์ติดต่อบีบีซี"/ORG, "บีบีซี"/ORG, "บีบีซีไม่มีส่วนรับผิดชอบต่อเนื้อหา"/ORG]
# The following NER tags are found:
# Span[0:1]: "อไทยทำ" → PER (0.9995)
# Span[8:9]: "มติรัฐสภา" → ORG (0.9959)
# Span[11:13]: "เศรษฐา ทวีสิน" → PER (0.9996)
# Span[17:18]: "เพื่อไทยปิดดีลรัฐบาล" → ORG (1.0)
# Span[26:28]: "BBC News" → ORG (1.0)
# Span[29:30]: "ไทยทำไมคุณจึงไว้วางใจ" → LOC (0.9712)
# Span[30:31]: "บีบีซี" → ORG (0.9941)
# Span[32:33]: "บีบีซีเกี่ยวกับบีบีซีนโยบายความเป็นส่วนตัวคุกกีส์ติดต่อบีบีซี" → ORG (0.7173)
# Span[42:43]: "บีบีซี" → ORG (0.9916)
# Span[44:45]: "บีบีซีไม่มีส่วนรับผิดชอบต่อเนื้อหา" → ORG (0.9959)
# Sentence[5]: "ของเว็บไซต์ภายนอก. นโยบายของเราเรื่องการเชื่อมต่อไปยังลิงก์ภายนอก. อ่านเกี่ยวกับแนวทางของเราในการติดต่อกับลิงก์ภายนอก"
# The following NER tags are found:
